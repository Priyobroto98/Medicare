# %%
# !pip install langchain
# Out:
# ...
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/cb/cc/684ac2410ad06957c17ffda787b7ff6c1595721c36c3b443c021e95cf998/langchain-0.1.11-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for dataclasses-json<0.7,>=0.5.7 from https://files.pythonhosted.org/packages/91/ca/7219b838086086972e662c19e908694bdc6744537fb41b70392501b8b5e4/dataclasses_json-0.6.4-py3-none-any.whl.metadata
#   Using cached dataclasses_json-0.6.4-py3-none-any.whl.metadata (25 kB)
# ...
#   Obtaining dependency information for jsonpatch<2.0,>=1.33 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# ...

# %%
pip install google-generativeai
# Out:
# ...
#   Obtaining dependency information for google-generativeai from https://files.pythonhosted.org/packages/ae/24/c282649e1b07cc2b8db6ce5d3293b526487fa011d7ed09fd4cac3a3f29af/google_generativeai-0.4.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for google-ai-generativelanguage==0.4.0 from https://files.pythonhosted.org/packages/40/c2/d28988d3cba74e712f47a498e2b3e3b58ac215106019bf5d8c20f8ab9822/google_ai_generativelanguage-0.4.0-py3-none-any.whl.metadata
#   Using cached google_ai_generativelanguage-0.4.0-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Obtaining dependency information for google-auth>=2.15.0 from https://files.pythonhosted.org/packages/92/94/35ba55b5011185ea1c995938e7851b25e6092f15658afa9263cd65a67dd4/google_auth-2.28.2-py2.py3-none-any.whl.metadata
# ...

# %%
pip install -U langchain-google-genai
# Out:
# ...
#   Obtaining dependency information for langchain-google-genai from https://files.pythonhosted.org/packages/08/8f/05b27a0732f152bfd7404f031833c3a94d066fe8e6c102b9658d31b69c7a/langchain_google_genai-0.0.9-py3-none-any.whl.metadata
#   Using cached langchain_google_genai-0.0.9-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Obtaining dependency information for google-generativeai<0.4.0,>=0.3.1 from https://files.pythonhosted.org/packages/b5/7f/35f89209487f8473edc9d2cecef894a54680cf666e32893a767d12a8dba9/google_generativeai-0.3.2-py3-none-any.whl.metadata
#   Using cached google_generativeai-0.3.2-py3-none-any.whl.metadata (5.9 kB)
# ...
# Using cached langchain_google_genai-0.0.9-py3-none-any.whl (17 kB)
# Using cached google_generativeai-0.3.2-py3-none-any.whl (146 kB)
# ...
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.4.0
#     Uninstalling google-generativeai-0.4.0:
#       Successfully uninstalled google-generativeai-0.4.0
# ...

# %%
import os
os.environ["GOOGLE_API_KEY"] = 'AIzaSyD3XwLkXOJXrV_4VYOTwgcpYPA5D5_UOmM'

# %%
from langchain_google_genai import GoogleGenerativeAI 

generation_config = {"temperature": 0.7, "top_p": 1, "top_k": 1, "max_output_tokens": 4000}

model = GoogleGenerativeAI(  model="gemini-pro", 
                           generation_config=generation_config  )

# %%
from langchain.chains import LLMChain

from langchain.prompts import PromptTemplate

prompt= PromptTemplate(
    
    input_variables=['age', 'weight', 'gender', 'height',  'foodtype', 'disease', 'yes_or_no', 'area,state,country'],
    template="Your HealthSync Advisor:\n"
             "you are an expert . now recommend me 6 breakfast names, 5 dinner names, and 6 workout names,"
               "based on the following data\n"
             " Age: {age}\n"
             "Weight: {weight}\n"
             "Gender: {gender}\n"
             "Height: {height}\n"
             " Dietary Preferences: {foodtype}\n"
             "Generic disease: {disease}\n"
             " Disability:{yes_or_no}\n"
             " Location: {area,state,country}\n"  
)

chain = LLMChain(llm=model, prompt=prompt,verbose=True)

# %%
input_data = {
    'age': 20,
    'weight': 64.35,
    'gender':'male',
    'height': 6,
    'foodtype': 'vegeterian',
    'disease': 'IBS',
    'yes_or_no': 'no',
    'area,state,country':'Durgapur,West Bengal,India'
}

# %%
 results = chain.invoke(input_data,verbose=True)
results_text=results['text']
print(results_text)
# Out:
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your HealthSync Advisor:
# you are an expert . now recommend me 6 breakfast names, 5 dinner names, and 6 workout names,based on the following data
#  Age: 20
# Weight: 64.35
# Gender: male
# Height: 6
#  Dietary Preferences: vegeterian
# Generic disease: IBS
#  Disability:no
#  Location: Durgapur,West Bengal,India
#
#
# > Finished chain.
# **Breakfast Names:**
#
# 1. Oatmeal with berries and nuts
# 2. Tofu scramble with vegetables
# 3. Yogurt with fruit and granola
# 4. Whole-wheat toast with avocado and hummus
# 5. Quinoa breakfast bowl with fruit and nuts
# 6. Smoothie made with fruits, vegetables, and plant-based milk
#
# **Dinner Names:**
#
# 1. Lentil soup with brown rice
# 2. Vegetarian chili
# 3. Tofu stir-fry with vegetables
# 4. Black bean tacos with brown rice
# 5. Quinoa salad with roasted vegetables
#
# **Workout Names:**
#
# 1. Brisk walking
# 2. Jogging
# 3. Swimming
# 4. Cycling
# 5. Yoga
# 6. Pilates

# %%
import re

# The input text containing breakfast, dinner, and workout recommendations
input_text = results_text

# Regular expressions to extract recommendations
breakfast_pattern = re.compile(r"Breakfast Names:(.*?)Dinner Names:", re.DOTALL)
dinner_pattern = re.compile(r"Dinner Names:(.*?)Workout Names:", re.DOTALL)
workout_pattern = re.compile(r"Workout Names:(.*)", re.DOTALL)

# Extract recommendations
breakfast_matches = breakfast_pattern.search(input_text)
dinner_matches = dinner_pattern.search(input_text)
workout_matches = workout_pattern.search(input_text)

# Clean up the extracted lists
def clean_recommendations(recommendations):
    return [line.strip() for line in recommendations.split("\n") if line.strip()]

breakfast_recommendations = clean_recommendations(breakfast_matches.group(1))
dinner_recommendations = clean_recommendations(dinner_matches.group(1))
workout_recommendations = clean_recommendations(workout_matches.group(1))

# Print the recommendations separately
print("Breakfast Recommendations:")
for i, recommendation in enumerate(breakfast_recommendations, start=1):
    if recommendation.strip() != "**":
        print(recommendation.strip())

print("\nDinner Recommendations:")
for i, recommendation in enumerate(dinner_recommendations, start=1):
    if recommendation.strip() != "**":
        print(recommendation.strip())

print("\nWorkout Recommendations:")
for i, recommendation in enumerate(workout_recommendations, start=1):
    if recommendation.strip() != "**":
        print(recommendation.strip())
# Out:
# Breakfast Recommendations:
# 1. Oatmeal with berries and nuts
# 2. Tofu scramble with vegetables
# 3. Yogurt with fruit and granola
# 4. Whole-wheat toast with avocado and hummus
# 5. Quinoa breakfast bowl with fruit and nuts
# 6. Smoothie made with fruits, vegetables, and plant-based milk
#
# Dinner Recommendations:
# 1. Lentil soup with brown rice
# 2. Vegetarian chili
# 3. Tofu stir-fry with vegetables
# 4. Black bean tacos with brown rice
# 5. Quinoa salad with roasted vegetables
#
# Workout Recommendations:
# 1. Brisk walking
# 2. Jogging
# 3. Swimming
# 4. Cycling
# 5. Yoga
# 6. Pilates
